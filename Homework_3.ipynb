# %% [markdown]
# ## 1. Найдите собственные векторы и собственные значения для линейного оператора, заданного матрицей:

# %%
import numpy as np
A1 = np.array([[-1, -6],[2, 6]])
w, v = np.linalg.eig(A1)
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# (-1 - L)(6 - l) + 12 = 0 => L^2 -5L + 6 = 0 = (L1 = 3)(L2 = 2)
# print("Собственные значерня равны 2 и 3")
# -4x1 -6x2 = 0 
# -1x1 6x2 = 0

# -2x1 = 3x2
# x1 = 6x2
# собственные вектора для первого L1 будут равны ?
# Тут не понял как сделать
# Out:
# Собственные значения:
# [2. 3.]
# Собственные векторы:
# [[-0.89442719  0.83205029]
#  [ 0.4472136  -0.5547002 ]]

# %% [markdown]
# ## 2. Дан оператор поворота на 180 градусов, задаваемый матрицей: покажите, что любой вектор считается для него собственным.

# %%
A2 = np.array([[-1, 0],[0, -1]])
w, v = np.linalg.eig(A2)
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# так как собственный вектор равен матрице ниже, то мы получаем, что любой вектор является его собственным, так как изменяется 
# лишь его размер без поворота. Из этого следует, что любой вектор является собственным и коллинеарен прообразу исходной матрицы
# поворота
# Out:
# Собственные значения:
# [-1. -1.]
# Собственные векторы:
# [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# ## 3.Установите, считается ли вектор  𝑥=(1,1)  собственным вектором этого линейного оператора.

# %%
A3 = np.array([[1, 1],[-1, 3]])
# (1-l)(3-l)+1 = 0 
# 3 -3l + -l + l^2 + 1 = 0
# l^2  - 4l + 4 = 0
# l1 = 2    x1 = x2
# в связи с этим вектор x=(1,1) является собственным вектором линейного оператора

# %% [markdown]
# ## Установите, считается ли вектор  𝑥=(3,−3,−4)  собственным вектором этого линейного оператора.

# %%
A4 = np.array([[0, 3, 0],[3, 0, 0],[0, 0, 3]])
#  L = 3
# вектор не считается собственным вектором линейного оператора, так как минимум его х3 = 0
