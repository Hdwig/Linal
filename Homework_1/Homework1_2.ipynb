# %% [markdown]
# 1. Исследуйте на линейную зависимость:
#
# 𝑓1(𝑥)=𝑒𝑥,𝑓2(𝑥)=1,𝑓3(𝑥)=𝑥+1,𝑓4(𝑥)=𝑥−𝑒𝑥.

# %%
# (ex) + (1) + (x + 1) + (x - ex) = 0
# Комбинация векторов является зависимой, так как если при f3 поставить коэффициент равный -1, то будет:
# ex + 1 + x - ex = -1 * (-x - 1)  => 1 + x = x + 1

# %%
2. Исследуйте на линейную зависимость:
𝑓1(𝑥)=2,𝑓2(𝑥)=𝑥,𝑓3(𝑥)=𝑥^2,𝑓4(𝑥)=(𝑥+1)^2

# %%
# при раскрытии скобок и переносе f4 в другую половину уравнения, мы получаем:
2 + x + x^2 = -(x^2 + 2x + 1)
#  при детальном рассмотрении сразу видно, что с обеих сторон все одинаковое, лишь осталось добавить коэффициенты
1/2(2) + 2(x) + x^2 = -1(-(x^2 + 2x + 1)) => 1 + 2x + x^2 = x^2 + 2x + 1
# Из этого делаем вывод, что векторы зависимы

# %%
3. Найдите координаты вектора 𝑥=(2,3,5)∈ℝ3 в базисе 𝑏1=(0,0,10), 𝑏2=(2,0,0), 𝑏3=(0,1,0).

# %%
1/2(b1), 1(b2), 3(b3)

# %%
4. Найдите координаты вектора 3𝑥^2−2𝑥+2∈ℝ^3[𝑥]:

а) в базисе 1, 𝑥, 𝑥^2;

б) в базисе 𝑥2, 𝑥−1, 1.

# %%
a) 2e1 + (-2e2) + 3e3
б) 3e1 + (-2e2) + 0e3

# %%
5. Установите, считается ли линейным подпространством:

а) совокупность всех векторов трёхмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;

б) все векторы, считающиеся линейными комбинациями данных векторов {𝑢1,𝑢2…,𝑢𝑛}.

# %%
a) Подмножество всех свободных векторов, параллельных некоторой плоскости, 
считается подпространством линейного пространства всех свободных векторов в трёхмерном пространстве.
в связи с этим, мы можем сказать, что оно считается линейный подпространством, так как выволняются оба обязательных условия 
подпространства:
1) 𝑢+𝑣∈𝐿; 
2) 𝛼⋅𝑢∈𝐿.
(Задачку данного типа мы уже решали в процессе урока)
б)совокупность всех линейных комбинаций этих векторов образует некоторое подпространство исходного линейного пространства.
Она будет называться линейной оболочкой, которая будет входить в это подпространство.
Если вектора {𝑢1,𝑢2…,𝑢𝑛}, входят в подпространство, то и их комбинации будут входить в данное подпространство
